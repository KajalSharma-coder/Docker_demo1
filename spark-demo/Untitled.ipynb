# %%
import os

print("SPARK_HOME =", os.environ.get("SPARK_HOME"))
print("JAVA_HOME =", os.environ.get("JAVA_HOME"))
# Out:
# SPARK_HOME = C:\Users\amitk\Downloads\spark-4.1.2-bin-hadoop3\spark-4.1.2-bin-hadoop3
# JAVA_HOME = C:\Program Files\Java\jdk-21.0.11

# %%
import os

spark_home = os.environ.get("SPARK_HOME")

if spark_home:
    print(os.path.exists(os.path.join(spark_home, "bin", "spark-submit")))
else:
    print("SPARK_HOME not set")
# Out:
# True

# %%
import pyspark

print(pyspark.__version__)
# Out:
# 4.1.2
